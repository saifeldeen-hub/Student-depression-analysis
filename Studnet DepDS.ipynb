# %% [markdown]
# # Importing Libiraies

# %%
import pandas as pd
import matplotlib.pyplot as pt
import seaborn as sb
import plotly.express as plt

# %%
df=pd.read_csv('student_depression_dataset.csv')

# %%
df
# Out:
#            id  Gender   Age           City Profession  Academic Pressure  \
# 0           2    Male  33.0  Visakhapatnam    Student                5.0
# 1           8  Female  24.0      Bangalore    Student                2.0
# 2          26    Male  31.0       Srinagar    Student                3.0
# 3          30  Female  28.0       Varanasi    Student                3.0
# 4          32  Female  25.0         Jaipur    Student                4.0
# ...       ...     ...   ...            ...        ...                ...
# 27896  140685  Female  27.0          Surat    Student                5.0
# 27897  140686    Male  27.0       Ludhiana    Student                2.0
# 27898  140689    Male  31.0      Faridabad    Student                3.0
# 27899  140690  Female  18.0       Ludhiana    Student                5.0
# 27900  140699    Male  27.0          Patna    Student                4.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# ...

# %%
df.info()

# %%
df[df['Profession']!="Student"]

# %% [markdown]
# # Rows Cleaning

# %%
df["Profession"] = df["Profession"].str.replace("'", "", regex=False)

# %%
df[df['Profession']!="Student"]
# Out:
#            id  Gender   Age           City              Profession  \
# 113       609    Male  21.0      Ahmedabad          Civil Engineer
# 422      2105  Female  31.0       Vadodara               Architect
# 1845     9483  Female  32.0         Kalyan          UX/UI Designer
# 2249    11470  Female  28.0      Ahmedabad        Digital Marketer
# 2440    12425    Male  25.0         Kalyan          Content Writer
# 3220    16196    Male  33.0         Jaipur               Architect
# 3388    16959  Female  24.0         Mumbai               Architect
# 3639    18291    Male  32.0           Agra  Educational Consultant
# 3841    19226    Male  31.0         Rajkot                 Teacher
# 5016    25193    Male  24.0         Kalyan                 Teacher
# 8537    43035    Male  23.0          Patna                 Manager
# 12124   61219  Female  23.0         Kalyan                    Chef
# 12350   62410  Female  34.0      Ghaziabad          Content Writer
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27901 entries, 0 to 27900
# Data columns (total 18 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     27901 non-null  int64
#  1   Gender                                 27901 non-null  object
#  2   Age                                    27901 non-null  float64
#  3   City                                   27901 non-null  object
#  4   Profession                             27901 non-null  object
#  5   Academic Pressure                      27901 non-null  float64
#  6   Work Pressure                          27901 non-null  float64
#  7   CGPA                                   27901 non-null  float64
#  8   Study Satisfaction                     27901 non-null  float64
#  9   Job Satisfaction                       27901 non-null  float64
# ...

# %% [markdown]
# Profession to Acadimic Pressure

# %%
pt.figure(figsize=(10,10))
pt.bar(df['Profession'], df['Academic Pressure'])
pt.ylabel("Academic Pressure")
pt.xlabel("Profession")
pt.title("Profession to Academic pressure")
pt.xticks(rotation=90)
pt.legend()
pt.show()

# %% [markdown]
# # Profession to Work Pressure

# %%
pt.figure(figsize=(10,10))
pt.bar(df['Profession'], df['Work Pressure'])
pt.ylabel("Work Pressure")
pt.xlabel("Profession")
pt.title("Profession to Work pressure")
pt.xticks(rotation=90)
pt.legend()
pt.show()

# %% [markdown]
# # Profession to study Satisifaction

# %%
pt.figure(figsize=(10,10))
pt.bar(df['Profession'], df['Study Satisfaction'])
pt.ylabel("Study Satisfaction")
pt.xlabel("Profession")
pt.title("Profession to Study Satisfaction")
pt.xticks(rotation=90)
pt.legend()
pt.show()

# %% [markdown]
# # Profession to Job satisfaction

# %%
pt.figure(figsize=(10,10))
pt.bar(df['Profession'], df['Job Satisfaction'])
pt.ylabel("Job Satisfaction")
pt.xlabel("Profession")
pt.title("Profession to Job Satisfaction")
pt.xticks(rotation=90)
pt.legend()
pt.show()

# %% [markdown]
# # Profession To Financial strees

# %% [markdown]
# There were missing values in the financial strees
# so the mean of values offinancial strees were modified in 3 rows

# %%
df['Financial Stress'].unique()
# Out:
# array(['1.0', '2.0', '5.0', '3.0', '4.0', '?'], dtype=object)

# %%
df[df['Financial Stress']=="?"]
# Out:
#           id  Gender   Age       City Profession  Academic Pressure  \
# 4458   22377  Female  32.0   Varanasi    Student                3.0
# 13596  68910    Male  29.0  Hyderabad    Student                2.0
# 19266  97610  Female  20.0    Kolkata    Student                1.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 4458             0.0  5.64                 1.0               0.0
# 13596            0.0  8.94                 3.0               0.0
# 19266            0.0  6.83                 1.0               0.0
#
#             Sleep Duration Dietary Habits Degree  \
# 4458           '5-6 hours'        Healthy    BCA
# 13596  'Less than 5 hours'      Unhealthy   B.Ed
# 19266          '5-6 hours'        Healthy   MBBS
#
#       Have you ever had suicidal thoughts ?  Work/Study Hours  \
# 4458                                     No              12.0
# 13596                                    No              12.0
# ...

# %%
# Change the profession of the person in row 4458
df.loc[4458	, "Financial Stress"] = "3.0"
# Change the profession of the person in row 13596
df.loc[13596, "Financial Stress"] = "3.0"
# Change the profession of the person in row 19266
df.loc[19266, "Financial Stress"] = "3.0"

# %%
students=df[df['Profession']=="Student"]

# %%
pt.figure(figsize=(14, 8))
sb.countplot(data=df, x='Profession', hue='Financial Stress')
pt.title('Students to Financial Presentation')
pt.ylabel('Count')
pt.xlabel('Profession')
pt.xticks(rotation=90)
pt.tight_layout()

pt.show()

# %% [markdown]
# # Financial Stress Student

# %%
pt.figure(figsize=(14, 8))
ax=sb.countplot(data=students, x='Profession', hue='Financial Stress')
pt.title('Students to Financial Presentation')
pt.ylabel('Count')
pt.xlabel('Profession')
pt.xticks(rotation=90)
pt.tight_layout()
for p in ax.patches:
    height = p.get_height()
    if height > 0:
        ax.annotate(f'{int(height)}', 
                    (p.get_x() + p.get_width() / 2., height),
                    ha='center', va='bottom', fontsize=8, rotation=0)
pt.show()

# %% [markdown]
# # Financial stress non students

# %%
non_stud=df[df['Profession']!="Student"]

# %%
non_stud['Financial Stress'].unique()

# %%
non_stud['Financial Stress'] = non_stud['Financial Stress'].astype(str).str.strip().str.replace("'", "", regex=False)
non_stud['Financial Stress']=non_stud['Financial Stress'].astype(float)

# %%
non_stud['Financial Stress'].dtype

# %%
len(non_stud)

# %%
pt.figure(figsize=(14, 8))
sb.countplot(data=non_stud, x='Profession', hue='Financial Stress')
pt.title('Non-Student Profession to Financail Stress Presentation')
pt.ylabel('Count')
pt.xlabel('Profession')
pt.xticks(rotation=90)
pt.yticks()
pt.tight_layout()
pt.show()

# %%
len(df[df['Profession']=="Architect"])

# %%
pt.figure(figsize=(8, 6))
ax=sb.countplot(data=students, x='Profession', hue='Family History of Mental Illness')
pt.title('Student to Family illenst history Presentation')
pt.ylabel('Count')
pt.xlabel('Profession')
pt.xticks(rotation=90)
pt.tight_layout()
for p in ax.patches:
    height = p.get_height()
    if height > 0:
        ax.annotate(f'{int(height)}', 
                    (p.get_x() + p.get_width() / 2., height),
                    ha='center', va='bottom', fontsize=8, rotation=0)
pt.show()

# %%
pt.figure(figsize=(8, 6))
ax=sb.countplot(data=non_stud, x='Profession', hue='Family History of Mental Illness')
pt.title('Non-Student Profession to Family illenst history Presentation')
pt.ylabel('Count')
pt.xlabel('Profession')
pt.xticks(rotation=90)
pt.tight_layout()
for p in ax.patches:
    height = p.get_height()
    if height > 0:
        ax.annotate(f'{int(height)}', 
                    (p.get_x() + p.get_width() / 2., height),
                    ha='center', va='bottom', fontsize=8, rotation=0)
pt.show()

# %%
pt.figure(figsize=(10, 6))
ax=sb.countplot(data=students, x='Profession', hue='Have you ever had suicidal thoughts ?')
pt.title('Students vs Have you ever had suicidal thoughts ?	')
pt.xticks(rotation=90)
pt.tight_layout()
for p in ax.patches:
    height = p.get_height()
    if height > 0:
        ax.annotate(f'{int(height)}', 
                    (p.get_x() + p.get_width() / 2., height),
                    ha='center', va='bottom', fontsize=8, rotation=0)
pt.show()

# %% [markdown]
# # Suicidal Thoughts non Student

# %%
pt.figure(figsize=(10, 6))
ax=sb.countplot(data=non_stud, x='Profession', hue='Have you ever had suicidal thoughts ?')
pt.title('Non-Student Profession vs Have you ever had suicidal thoughts ?	')
pt.xticks(rotation=90)
pt.tight_layout()
for p in ax.patches:
    height = p.get_height()
    if height > 0:
        ax.annotate(f'{int(height)}', 
                    (p.get_x() + p.get_width() / 2., height),
                    ha='center', va='bottom', fontsize=8, rotation=0)
pt.show()

# %% [markdown]
# # Students sleep Duration

# %%
pt.figure(figsize=(10, 6))
ax=sb.countplot(data=students, x='Profession', hue='Sleep Duration')
pt.title('Students vs Sleep duration')
pt.xticks(rotation=90)
pt.tight_layout()
for p in ax.patches:
    height = p.get_height()
    if height > 0:
        ax.annotate(f'{int(height)}', 
                    (p.get_x() + p.get_width() / 2., height),
                    ha='center', va='bottom', fontsize=8, rotation=0)
pt.show()

# %% [markdown]
# # Non Students vs sleep duration

# %%
pt.figure(figsize=(10, 6))
ax=sb.countplot(data=non_stud, x='Profession', hue='Sleep Duration')
pt.title('Students vs Sleep duration')
pt.xticks(rotation=90)
pt.tight_layout()
for p in ax.patches:
    height = p.get_height()
    if height > 0:
        ax.annotate(f'{int(height)}', 
                    (p.get_x() + p.get_width() / 2., height),
                    ha='center', va='bottom', fontsize=8, rotation=0)
pt.show()

# %%
pt.figure(figsize=(10, 6))
ax=sb.countplot(data=students, x='Profession', hue='Dietary Habits')
pt.title('Students vs Dietary Habits')
pt.xticks(rotation=90)
pt.tight_layout()
for p in ax.patches:
    height = p.get_height()
    if height > 0:
        ax.annotate(f'{int(height)}', 
                    (p.get_x() + p.get_width() / 2., height),
                    ha='center', va='bottom', fontsize=8, rotation=0)
pt.show()

# %%
pt.figure(figsize=(10, 6))
ax=sb.countplot(data=non_stud, x='Profession', hue='Dietary Habits')
pt.title('Non students Profession vs Dietary Habits')
pt.xticks(rotation=90)
pt.tight_layout()
for p in ax.patches:
    height = p.get_height()
    if height > 0:
        ax.annotate(f'{int(height)}', 
                    (p.get_x() + p.get_width() / 2., height),
                    ha='center', va='bottom', fontsize=8, rotation=0)
pt.show()

# %% [markdown]
# # Student depression

# %%
pt.figure(figsize=(10, 6))
ax=sb.countplot(data=students, x='Profession', hue='Depression')
pt.title('Students vs Dietary Habits')
pt.xticks(rotation=90)
pt.tight_layout()
for p in ax.patches:
    height = p.get_height()
    if height > 0:
        ax.annotate(f'{int(height)}', 
                    (p.get_x() + p.get_width() / 2., height),
                    ha='center', va='bottom', fontsize=8, rotation=0)
pt.show()

# %% [markdown]
# # Non student depression

# %%
pt.figure(figsize=(10, 6))
ax=sb.countplot(data=non_stud, x='Profession', hue='Depression')
pt.title('Students vs Dietary Habits')
pt.xticks(rotation=90)
pt.tight_layout()
for p in ax.patches:
    height = p.get_height()
    if height > 0:
        ax.annotate(f'{int(height)}', 
                    (p.get_x() + p.get_width() / 2., height),
                    ha='center', va='bottom', fontsize=8, rotation=0)
pt.show()

# %% [markdown]
# # CGPA histplot

# %%
ax=sb.histplot(data=students,x='CGPA',bins=30,kde=True, hue='Profession')
pt.title('CGPA Histplot')
pt.show()

# %%
pt.figure(figsize=(12,12))
ax=sb.histplot(data=non_stud,x='CGPA',bins=30,kde=False, hue='Profession')
pt.title('CGPA Histplot')
pt.show()

# %% [markdown]
# # Age histo

# %%
pt.figure(figsize=(12,12))
ax=sb.histplot(data=students,x='Age',bins=30,kde=False, hue='Profession')
pt.title('Age Students Histplot')
for p in ax.patches:
    height = p.get_height()
    if height > 0:
        ax.annotate(f'{int(height)}', 
                    (p.get_x() + p.get_width() / 2., height),
                    ha='center', va='bottom', fontsize=8, rotation=0)
pt.show()

# %%
sb.boxplot(data=non_stud,x='Profession',y='Age')
pt.xticks(rotation=90)
pt.title('Age to Distribu')

# %%
with pd.ExcelWriter("Analysis Data Mod.xlsx") as writer:
    df.to_excel(writer,sheet_name='Student',index=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27901 entries, 0 to 27900
# Data columns (total 18 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     27901 non-null  int64
#  1   Gender                                 27901 non-null  object
#  2   Age                                    27901 non-null  float64
#  3   City                                   27901 non-null  object
#  4   Profession                             27901 non-null  object
#  5   Academic Pressure                      27901 non-null  float64
#  6   Work Pressure                          27901 non-null  float64
#  7   CGPA                                   27901 non-null  float64
#  8   Study Satisfaction                     27901 non-null  float64
#  9   Job Satisfaction                       27901 non-null  float64
# ...

# %%
non_stud
# Out:
#            id  Gender   Age           City              Profession  \
# 113       609    Male  21.0      Ahmedabad          Civil Engineer
# 422      2105  Female  31.0       Vadodara               Architect
# 1845     9483  Female  32.0         Kalyan          UX/UI Designer
# 2249    11470  Female  28.0      Ahmedabad        Digital Marketer
# 2440    12425    Male  25.0         Kalyan          Content Writer
# 3220    16196    Male  33.0         Jaipur               Architect
# 3388    16959  Female  24.0         Mumbai               Architect
# 3639    18291    Male  32.0           Agra  Educational Consultant
# 3841    19226    Male  31.0         Rajkot                 Teacher
# 5016    25193    Male  24.0         Kalyan                 Teacher
# 8537    43035    Male  23.0          Patna                 Manager
# 12124   61219  Female  23.0         Kalyan                    Chef
# 12350   62410  Female  34.0      Ghaziabad          Content Writer
# ...

# %%
with pd.ExcelWriter("StudentDepDS.xlsx") as writer:
    df.to_excel(writer,sheet_name='Student',index=True)
    non_stud.to_excel(writer,sheet_name='Non-studnet',index=True)
